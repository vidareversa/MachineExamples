# %%
import pandas as pd
import os as os
import matplotlib.pyplot as plt
import numpy as np


mainpath   = '/home/facu/Escritorio/python-ml-course/datasets';
filename   = 'musix.xlsx';
fullpath   = os.path.join(mainpath, filename);
data       = pd.read_excel(fullpath, "1");

data

plt.scatter(data["tiempo"],data["popeye"],color='k')
plt.scatter(data["tiempo"],data["estrellita"],color='k')
plt.scatter(data["tiempo"],data["inconciente"],color='k')
plt.scatter(data["tiempo"],data["corazon"],color='k')



#data.describe()
#d = data.mean(axis=1)

#d
#plt.scatter(data["tiempo"],d,color='k')

# %%
data.describe()
data.head()
canciones = data.iloc[:, 2:6] # Primeras cinco columnas
d = round(canciones.mean(axis=1))
#d = data.mean(axis=1)
#d
plt.scatter(data["tiempo"],d,color='k')

# %%
plt.plot(d)   # Dibuja el gráfico
plt.title("Título")   # Establece el título del gráfico
plt.xlabel("Abscisa")   # Establece el título del eje x
plt.ylabel("Ordenada")   # Establece el título del eje y
# Out:
# Text(0, 0.5, 'Ordenada')

# %%
d [mi, re, si, mi, la, si, si, do, do, do, do, fa, sol, mi, la, la, la, si]
# Out:
# 0      3.0
# 1      9.0
# 2      7.0
# 3     10.0
# 4      6.0
# 5      7.0
# 6      7.0
# 7      8.0
# 8      8.0
# 9      8.0
# 10     8.0
# 11     4.0
# 12     5.0
# 13     3.0
# 14     6.0
# 15     6.0
# 16     6.0
# 17     7.0
# 18     5.0
# 19     7.0
# 20     5.0
# 21     8.0
# 22     6.0
# 23     8.0
# 24     6.0
# 25     7.0
# 26     6.0
# 27     6.0
# 28     6.0
# 29     NaN
# 30     7.0
# 31     NaN
# 32     6.0
# 33     6.0
# 34     4.0
# 35     6.0
# 36     3.0
# 37     6.0
# 38     6.0
# 39     5.0
# dtype: float64
